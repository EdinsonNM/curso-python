# %% [markdown]
# ## Bucles
#  Las estructuras de iteración permiten repetir secciones de código. A menudo se denominan bucles porque permiten al programa volver a una línea ya ejecutada. El proceso de ejecutar una repetición de un bucle también se conoce como iteración del bucle.
#
# ### WHILE
# Un bucle while es una estructura de iteracción que:
# - Repite un bloque de código mientras una condición sea verdadera
# - No depende de “cuántas veces”, sino de cuándo cambia algo

# %%
while condicion:
    # código que se repite

# %% [markdown]
# 🚨 Regla clave
#
# - Todo while necesita una forma de terminar.
# - Si la condición nunca cambia → se crea un bucle infinito.
# - Ejemplo peligroso:

# %%
while True:
    print("Hola")

# %% [markdown]
# - Esto nunca se detiene.

# %% [markdown]
# ⚙️ Elementos de un while
#
# 1. Variable inicial
# 2. Condición
# 3. Cambio dentro del bucle

# %%
contador = 0

while contador < 5:
    print(contador)
    contador += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# #### Ejemplos

# %% [markdown]
# 🍫 Ejemplo 1 — Comprar chocolates hasta que se acabe el dinero

# %%
dinero = 20

while dinero > 0:
    print("Comprando chocolate ❤️")
    dinero -= 5
# Out:
# Comprando chocolate ❤️
# Comprando chocolate ❤️
# Comprando chocolate ❤️
# Comprando chocolate ❤️

# %% [markdown]
# 💌 Ejemplo 2 — Intentar conquistar hasta lograr un “sí”

# %%
# "! =" significa diferente si junto estos dos caracteres
respuesta = "no"
while respuesta != "si":
    respuesta = input("¿Quieres ser mi Valentín? ")
    
print("¡Sabía que dirías que sí! ❤️")
# Out:
# ¡Sabía que dirías que sí! ❤️

# %% [markdown]
# 🎁 Ejemplo 3 — Buscar el regalo perfecto

# %%
regalo_encontrado = False

while regalo_encontrado == False:
    print("Buscando regalo perfecto...")
    regalo_encontrado = True #cambio
print("Regalo encontrado")
# Out:
# Buscando regalo perfecto...
# Regalo encontrado

# %% [markdown]
# 💔 Ejemplo 4 — Bucle infinito (el crush eterno)
#
# - Todo while necesita una forma de terminar.
# - Si la condición nunca cambia → se crea un bucle infinito.
#
# Ejemplo peligroso:

# %%
while True:
    print("Pensando en ti...")

# %% [markdown]
# 🛑 ¿Qué es break?
#
# break es una palabra reservada de Python que se utiliza para salir inmediatamente de un bucle (while o for), interrumpiendo su ejecución aunque la condición del bucle siga siendo verdadera.

# %%
while True:
    numero = int(input("Escribe un número: "))

    if numero == 5:#comparación
        print("Número encontrado")
        break
# Out:
# Número encontrado

# %% [markdown]
# ### Ejercicios

# %% [markdown]
# #### 💘 Ejercicio1 : "El repartidor explotado emocionalmente"
#
# - Eres nuevo en la florería. Tu jefe te dice: *“No regreses hasta entregar 10 rosas… y si lloras, igual sigues”*. Debes mostrar cada rosa entregada hasta llegar a 10.

# %%
# aquí el código
contador = 1
while contador <= 10:
    print(f"Entregando rosa {contador}")
    contador += 1
# Out:
# Entregando rosa 1
# Entregando rosa 2
# Entregando rosa 3
# Entregando rosa 4
# Entregando rosa 5
# Entregando rosa 6
# Entregando rosa 7
# Entregando rosa 8
# Entregando rosa 9
# Entregando rosa 10

# %% [markdown]
# #### 💘 Ejercicio 2 :  El amigo intenso que nadie pidió
#
# Tu amigo acaba de enamorarse y ahora manda mensajes como loco. Debe escribir:   Te extraño ❤️ hasta haberlo enviado 5 veces.
#
# _(Sí, sabemos que lo van a ignorar, pero él insiste.)_

# %%
# aquí tu código
contador=1
while contador <= 5:
    print("Te extraño ❤️")
    contador += 1
# Out:
# Te extraño ❤️
# Te extraño ❤️
# Te extraño ❤️
# Te extraño ❤️
# Te extraño ❤️

# %% [markdown]
# #### 💘 Ejercicio 3 : El enamorado sin dinero
#
# Tienes 30 soles, San Valentín encima y cero planificación financiera.
#
# Cada chocolate cuesta 6.
#
# Compra hasta quedarte sin dinero y muestra cada compra.
#
# _(La educación financiera claramente no llegó a tiempo.)_

# %%
# aquí tu código
dinero = 30
while dinero > 0:
    dinero -= 6
    print("Comprando chocolate ❤️", dinero)
# Out:
# Comprando chocolate ❤️ 24
# Comprando chocolate ❤️ 18
# Comprando chocolate ❤️ 12
# Comprando chocolate ❤️ 6
# Comprando chocolate ❤️ 0

# %% [markdown]
# #### 💘 Ejercicio 4 : El crush nivel jefe final
# 🟡 Nivel intermedio
#
# Intentas invitar a salir a alguien.
# El programa debe seguir preguntando: **¿Aceptas salir conmigo?** hasta que la respuesta sea "si".
#
# _(Advertencia: puede tardar.)_

# %%
# aquí tu código
respuesta="no"
while respuesta != "si":
    respuesta = input("¿Aceptas salir conmigo? ")# si, no
    if respuesta!="si":
        print("Bueno... seguimos intentando 😐")
    else:
        print("¡Aceptó la cita! ❤️ Misión cumplida")
# Out:
# Bueno... seguimos intentando 😐
# ¡Aceptó la cita! ❤️ Misión cumplida

# %%
while True:
    respuesta=input("¿Aceptas salir conmigo? ")
    if respuesta=="si":
        print("cita confirmada! ❤️ Misión cumplida")
        break
    else:
        print("Bueno... seguimos intentando 😐")
# Out:
# Bueno... seguimos intentando 😐
# Bueno... seguimos intentando 😐
# Bueno... seguimos intentando 😐
# cita confirmada! ❤️ Misión cumplida

# %% [markdown]
# #### 💘 Ejercicio 5 : El celular del enamorado paranoico
#
# Quieres ver si te respondieron el mensaje. Pero el celular está bloqueado.
# La contraseña es: **love2024**
# Sigue intentando hasta desbloquearlo.
#
# _(No, no es tóxico… solo curioso.)_

# %%
# aquí tu código
while True:
    contraseña = input("Introduce la contraseña: ")
    if(contraseña == "love2024"):
        print("Contraseña correcta, acceso concedido ❤️")
        break
    else:
        print("Contraseña incorrecta, intenta de nuevo 😐")
# Out:
# Contraseña incorrecta, intenta de nuevo 😐
# Contraseña incorrecta, intenta de nuevo 😐
# Contraseña incorrecta, intenta de nuevo 😐
# Contraseña correcta, acceso concedido ❤️

# %% [markdown]
# #### 💘 Ejercicio 6 : El poeta que nadie pidió
#
# Intentas escribir un poema romántico. El problema: te da cringe.
# Debes intentar 3 veces escribir uno mostrando: **Intento de poema...**

# %%
# aquí tu código

# %% [markdown]
# #### 💘 Ejercicio 7 : El organizador de citas improvisado
# 🟠 Nivel aplicado
#
# Decides planear San Valentín… a última hora.
#
# Menú: 1. Comprar flores 2. Reservar restaurante 3. Comprar regalo 4. Rendirse
# El programa se repite hasta que elijas rendirte.

# %%
# aquí tu código
while True:
    print("Menu de opciones:")
    print("1. Comprar flores")
    print("2. Reservar restaurante")
    print("3. Comprar regalo")
    print("4. Rendirse")
    opcion=input("Selecciona una opción: ")
    if opcion=="1":
        print("¡Flores compradas! 🌹")
    elif opcion=="2":
        print("¡Restaurante reservado! 🍽️")
    elif opcion=="3":
        print("¡Regalo comprado! 🎁")
    elif opcion=="4":
        print("¡No te rindas! ❤️")
        break
    else:
        print("Opción no válida, intenta de nuevo 😐")
# Out:
# Menu de opciones:
# 1. Comprar flores
# 2. Reservar restaurante
# 3. Comprar regalo
# 4. Rendirse
# ¡Restaurante reservado! 🍽️
# Menu de opciones:
# 1. Comprar flores
# 2. Reservar restaurante
# 3. Comprar regalo
# 4. Rendirse
# Opción no válida, intenta de nuevo 😐
# Menu de opciones:
# 1. Comprar flores
# 2. Reservar restaurante
# 3. Comprar regalo
# 4. Rendirse
# ¡No te rindas! ❤️

# %% [markdown]
# #### 💘 Ejercicio 8 : El ahorro romántico forzado
#
# Quieres comprar un regalo de 100 soles.
# Cada día ahorras lo que puedes (ingresado por el usuario). El programa sigue hasta alcanzar la meta.
#
# _(Porque el amor es fuerte… pero el sueldo no tanto.)_

# %%
# aquí tu código

# %% [markdown]
# #### 💘 Ejercicio 9 : El medidor de amor artificial
#
# Tu nivel de romanticismo empieza en 0. Cada acción romántica suma 10 puntos.
# Debe subir hasta llegar a 100.
#
# _(A partir de ahí oficialmente eres "material de relación estable".)_

# %%
# aquí tu código

# %% [markdown]
# #### 💘 Ejercicio 10 : El chatbot enamorado
# 🔴 Nivel reto
#
# Simula una conversación: usuario escribe algo, programa responde algo cursi.
# La conversación continúa hasta que el usuario escriba: **adios**
#
# _(Que es cuando el interés murió.)_

# %%
# aquí tu código

# %% [markdown]
# #### 💘 Ejercicio 11 : El amigo que no entiende indirectas
#
# Tu amigo sigue intentando conquistar a su crush.
# El sistema sigue mostrando **Intentando conquistar...** hasta que el usuario escriba: **ya me aceptó**
#
# _(O hasta que lo bloqueen… pero eso no lo programaremos.)_

# %%
# aquí tu código

# %% [markdown]
# #### 💘 Ejercicio 12 : El contador oficial de rechazos 💔
#
# Intentas invitar a alguien a salir. Cada "no" suma un rechazo.
# Cuando finalmente diga "sí", mostrar: **Aceptó después de X intentos ❤️**
#
# _(Esto es programación… y también estadística emocional.)_

# %%
# aquí tu código

# %% [markdown]
# #### 🧠 Ejercicio 13 : La misión San Valentín — Ejercicio estrella
#
# Eres tú. Sin plan. Sin presupuesto. Sin dignidad.
#
# El programa debe:
# 1. Pedir tu nombre.
# 2. Preguntar: ¿Aceptas una cita conmigo?
# 3. Si dice "no": Ok… intentaré otra estrategia… y volver a preguntar.
# 4. Si dice "si": ¡Tenemos cita, [nombre]! Increíblemente funcionó ❤️

# %%
# aquí tu código

# %% [markdown]
# #### 🎬 Ejercicio 14 : Simulador del enamorado persistente — Ejercicio final
#
# Contexto: Tienes un crush. No sabes hablar. Pero decides insistir.
#
# El programa debe repetir acciones:
# 1. Mandar mensaje 2. Comprar flores 3. Escribir poema 4. Esperar respuesta 5. Salir del intento
# Hasta que el usuario decida rendirse o diga que aceptaron la cita.

# %%
print("💘 Simulador del enamorado persistente 💘")

continuar = True

while continuar:
    print("\n¿Qué deseas hacer?")
    print("1. Mandar mensaje")
    print("2. Comprar flores")
    print("3. Escribir poema")
    print("4. Esperar respuesta")
    print("5. Salir del intento")

    opcion = input("Elige una opción: ")

    if opcion == "1":
        print("Mandaste un mensaje... ahora a esperar 😅")

    elif opcion == "2":
        print("Compraste flores 🌹... ojalá funcionen")

    elif opcion == "3":
        print("Escribiste un poema... nadie sabe si era buena idea")

    elif opcion == "4":
        respuesta = input("¿Te aceptaron la cita? (si/no): ")

        if respuesta == "si":
            print("¡Aceptó la cita! ❤️ Misión cumplida")
            continuar = False
        else:
            print("Bueno… seguimos intentando 😐")

    elif opcion == "5":
        print("Decidiste rendirte… el amor es duro 💔")
        continuar = False

    else:
        print("Opción inválida… ni en el amor ni en programación se improvisa así")
# Out:
# 💘 Simulador del enamorado persistente 💘
#
# ¿Qué deseas hacer?
# 1. Mandar mensaje
# 2. Comprar flores
# 3. Escribir poema
# 4. Esperar respuesta
# 5. Salir del intento
# Bueno… seguimos intentando 😐
#
# ¿Qué deseas hacer?
# 1. Mandar mensaje
# 2. Comprar flores
# 3. Escribir poema
# 4. Esperar respuesta
# 5. Salir del intento
# Decidiste rendirte… el amor es duro 💔
