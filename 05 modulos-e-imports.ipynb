# %% [markdown]
# ## 📘 Módulo 6: Módulos e Imports — Organiza tu código
#
# Cuando tu programa crece, escribir todo en un solo archivo se vuelve un caos. Los **módulos** te permiten dividir el código en archivos reutilizables y mantener todo ordenado.
#
# En este módulo aprenderás:
#
# | Tema | ¿Qué aprenderás? |
# | --- | --- |
# | **Módulo** | Qué es y para qué sirve |
# | **import** | Cómo cargar código de otros archivos |
# | **from ... import** | Importar solo lo que necesitas |
# | **Alias** | Dar nombres cortos a módulos largos |
# | **Proyecto** | Cómo organizar carpetas y archivos |
# | **__main__** | Ejecutar código solo cuando corres el archivo directamente |

# %% [markdown]
# ---
# ## 📦 ¿Qué es un módulo?
#
# ### Concepto
#
# Un **módulo** es un archivo `.py` que contiene definiciones de funciones, variables y clases. Cualquier archivo Python puede usarse como módulo.
#
# - **Archivo** `mi_modulo.py` → **Módulo** `mi_modulo`
# - El nombre del módulo es el nombre del archivo **sin** la extensión `.py`
# - Los módulos permiten **reutilizar** código sin copiar y pegar
# - Python incluye **módulos de la biblioteca estándar** (como `math`, `random`, `os`) que ya vienen instalados

# %% [markdown]
# ### Ejemplo: un archivo como módulo
#
# Si tienes un archivo `utils.py` con:
#
# ```python
# def saludar(nombre):
#     return f"Hola, {nombre}!"
#
# PI = 3.14159
# ```
#
# Ese archivo **es** el módulo `utils`. Puedes usarlo desde otro archivo importándolo.

# %% [markdown]
# ---
# ## 📥 Uso de `import`
#
# ### Sintaxis básica
#
# ```python
# import nombre_del_modulo
# ```
#
# Al importar todo el módulo, debes usar el **nombre del módulo** como prefijo para acceder a sus funciones y variables.
#
# ```python
# nombre_del_modulo.funcion()
# nombre_del_modulo.variable
# ```

# %% [markdown]
# ### Ejemplo con el módulo `math`
#
# El módulo `math` trae funciones matemáticas como `sqrt`, `pi`, `pow`, etc.

# %%
import math

print(math.sqrt(16))
print(f"El valor de pi es: {math.pi}")
print(f"2 a la potencia de 3 es: {math.pow(2, 3)}")
# Out:
# 4.0
# El valor de pi es: 3.141592653589793
# 2 a la potencia de 3 es: 8.0

# %% [markdown]
# ### Ejemplo con el módulo `random`
#
# El módulo `random` sirve para generar números aleatorios.

# %%
import random

print("Número aleatorio entre 1 y 10:", random.randint(1, 10))
print("Elemento aleatorio de una lista:", random.choice(["manzana", "plátano", "fresa"]))

# %% [markdown]
# ### Ventajas de `import modulo`
#
# | Ventaja | Explicación |
# | --- | --- |
# | **Claridad** | Sabes de dónde viene cada función |
# | **Sin conflictos** | No hay riesgo de sobrescribir nombres |
# | **Exploración** | Puedes usar `dir(modulo)` para ver qué contiene |

# %%
import math

# Ver qué contiene el módulo math
print("Contenido de math:", list(dir(math))[:10], "...")

# %% [markdown]
# ---
# ## 📤 `from ... import ...`
#
# ### Sintaxis
#
# En vez de importar todo el módulo, puedes traer **solo** lo que necesitas:
#
# ```python
# from nombre_modulo import funcion, variable
# ```
#
# Así usas las funciones **sin** el prefijo del módulo.

# %% [markdown]
# ### Ejemplo: importar funciones específicas

# %%
from math import sqrt, pi

# Ya no necesitas el prefijo math.
print("Raíz de 25:", sqrt(25))
print("Pi:", pi)

# %% [markdown]
# ### Importar todo con `*`
#
# ```python
# from math import *
# ```
#
# Trae **todas** las funciones y variables del módulo. ⚠️ **No se recomienda** porque puede generar conflictos de nombres y hace difícil saber de dónde viene cada cosa.

# %%
from math import sqrt, pi

# Ejemplo con sqrt y pi directamente
radio = 5
area = pi * (radio ** 2)
print(f"Área del círculo (radio={radio}): {area:.2f}")

# %% [markdown]
# ### Comparación rápida
#
# | Forma | Uso | Ejemplo |
# | --- | --- | --- |
# | `import math` | Con prefijo | `math.sqrt(16)` |
# | `from math import sqrt` | Sin prefijo | `sqrt(16)` |
# | `from math import sqrt, pi` | Varios | `sqrt(16)` y `pi` |

# %% [markdown]
# ---
# ## 🏷️ Alias de imports
#
# ### Concepto
#
# Un **alias** es un nombre corto que le das al módulo al importarlo. Se usa con la palabra `as`:
#
# ```python
# import nombre_largo as corto
# ```
#
# Muy útil cuando el nombre del módulo es largo o cuando quieres evitar conflictos.

# %% [markdown]
# ### Ejemplo: alias comunes

# %%
import math as m

print("Raíz de 100:", m.sqrt(100))
print("Pi:", m.pi)

# %%
import random as r

print("Número aleatorio:", r.randint(1, 50))
print("Elección aleatoria:", r.choice(["cara", "sello"]))

# %% [markdown]
# ### Alias con `from ... import`
#
# También puedes dar alias a funciones o variables importadas:

# %%
from math import sqrt as raiz_cuadrada

print("Raíz de 81:", raiz_cuadrada(81))
# Out:
# Raíz de 81: 9.0

# %% [markdown]
# ### Alias muy usados en la práctica
#
# | Módulo | Alias típico | Ejemplo |
# | --- | --- | --- |
# | `numpy` | `np` | `import numpy as np` |
# | `pandas` | `pd` | `import pandas as pd` |
# | `matplotlib.pyplot` | `plt` | `import matplotlib.pyplot as plt` |

# %% [markdown]
# ---
# ## 📁 Organización básica de un proyecto
#
# ### Estructura recomendada
#
# Para proyectos pequeños o medianos, una estructura típica es:
#
# ```
# mi_proyecto/
# ├── main.py           # Punto de entrada
# ├── utils.py          # Funciones auxiliares
# ├── config.py         # Configuración o constantes
# ├── datos/            # Carpeta para datos
# │   └── ...
# └── README.md        # Documentación
# ```
#
# Para proyectos más grandes, con varios módulos relacionados:
#
# ```
# mi_proyecto/
# ├── main.py
# ├── utils/
# │   ├── __init__.py   # Convierte la carpeta en paquete
# │   ├── helpers.py
# │   └── validadores.py
# ├── modelos/
# │   ├── __init__.py
# │   └── usuario.py
# └── README.md
# ```

# %% [markdown]
# ### Paquetes: carpetas con módulos
#
# Una **carpeta** con un archivo `__init__.py` se convierte en un **paquete**. Puedes importar así:
#
# ```python
# from utils.helpers import mi_funcion
# from modelos.usuario import Usuario
# ```

# %% [markdown]
# ### Ejemplo de estructura mínima
#
# ```python
# # config.py
# VERSION = "1.0"
# MAX_INTENTOS = 3
#
# # utils.py
# def formatear_nombre(nombre):
#     return nombre.strip().title()
#
# # main.py
# from config import VERSION
# from utils import formatear_nombre
#
# print(f"App v{VERSION}")
# print(formatear_nombre("  ana  "))  # Ana
# ```

# %% [markdown]
# ---
# ## ▶️ Uso del archivo `__main__`
#
# ### ¿Qué es `__main__`?
#
# Cuando ejecutas un archivo Python **directamente** (por ejemplo `python mi_archivo.py`), Python asigna el valor especial `"__main__"` a la variable `__name__`.
#
# Cuando ejecutas un archivo que **importa** ese módulo, `__name__` tiene el nombre del módulo, no `"__main__"`.
#
# Esto permite que un mismo archivo pueda:
# - **Ejecutarse** como programa principal (con pruebas o menú)
# - **Importarse** como módulo sin ejecutar código extra

# %% [markdown]
# ### Ejemplo: ver el valor de `__name__`
#
# En este notebook, cada celda se ejecuta en un contexto donde `__name__` es `"__main__"`.

# %%
print("Valor de __name__ en este contexto:", __name__)

# %% [markdown]
# ### Patrón típico con `if __name__ == "__main__":`
#
# ```python
# # mi_modulo.py
#
# def saludar(nombre):
#     return f"Hola, {nombre}!"
#
# if __name__ == "__main__":
#     # Solo se ejecuta cuando corres: python mi_modulo.py
#     print(saludar("Mundo"))
#     print("Pruebas del módulo...")
# ```
#
# Si otro archivo hace `import mi_modulo`, solo se cargará la función `saludar`, pero **no** se ejecutará el bloque `if __name__ == "__main__"`.

# %% [markdown]
# ### Uso del archivo `__main__.py` en paquetes
#
# En un **paquete** (carpeta con `__init__.py`), puedes crear un archivo `__main__.py` para que el paquete sea ejecutable:
#
# ```
# mi_paquete/
# ├── __init__.py
# ├── __main__.py   # Se ejecuta con: python -m mi_paquete
# └── ...
# ```
#
# Así puedes ejecutar: `python -m mi_paquete` y el código de `__main__.py` se ejecutará.

# %% [markdown]
# ### Simulación del patrón
#
# Aquí simulamos cómo funciona: si este fuera un archivo `.py` ejecutado directamente, el bloque se ejecutaría.

# %%
def saludar(nombre):
    return f"Hola, {nombre}!"

if __name__ == "__main__":
    print(saludar("Mundo"))
    print("✅ Este bloque solo se ejecuta cuando el archivo se corre directamente.")

# %% [markdown]
# ---
# ## ✏️ Práctica
#
# A continuación hay ejercicios para aplicar lo aprendido.

# %% [markdown]
# #### 📐 Ejercicio 1: La calculadora matemática
#
# Usa el módulo `math` para:
# 1. Calcular la raíz cuadrada de 144.
# 2. Usar `math.pi` para calcular el área de un círculo de radio 7.
# 3. Calcular el factorial de 5 con `math.factorial()`.
#
# _(Porque la calculadora del celular a veces no alcanza.)_

# %%
# Aquí tu código
from math import sqrt as raiz_cuadrada, pi, factorial

raiz = raiz_cuadrada(144)
print(raiz)
area = pi * 7**2
print(area)
factorial = factorial(5)
print(factorial)
# Out:
# 12.0
# 153.93804002589985
# 120

# %% [markdown]
# #### 🎲 Ejercicio 2: El dado virtual
#
# Usa el módulo `random` para:
# 1. Simular 5 tiradas de un dado (6 caras).
# 2. Elegir un país aleatorio de una lista de 5.
# 3. Mezclar una lista de 3 colores con `random.shuffle()` y mostrar el resultado.
#
# _(El dado que nunca pierdes.)_

# %%
import random

for i in range(5):
    dado = random.randint(1, 6)
    print("Lance el dado y salió:", dado)
    
paises = ["Argentina", "Brasil", "Chile", "Uruguay", "Paraguay"]
pais = random.choice(paises)
print("El país elegido es:", pais)

colores = ["rojo", "azul", "verde"]
random.shuffle(colores)
print("Colores mezclados:", colores)
# Out:
# Lance el dado y salió: 1
# Lance el dado y salió: 5
# Lance el dado y salió: 4
# Lance el dado y salió: 3
# Lance el dado y salió: 1
# El país elegido es: Brasil
# Colores mezclados: ['rojo', 'azul', 'verde']

# %% [markdown]
# #### 🏷️ Ejercicio 3: Alias en acción
#
# Importa `math` con el alias `m` y `random` con el alias `r`.
# Usa ambos para calcular:
# - Un número aleatorio entre 1 y 100.
# - La raíz cuadrada de ese número (usando `m.sqrt`).
#
# _(Menos tecleo, más productividad.)_

# %%
import math as m
import random as r
numero_aleatorio=r.randint(1, 100)
raiz = m.sqrt(numero_aleatorio)

print("El número aleatorio es:", numero_aleatorio)
print("La raíz cuadrada de ese número es:", raiz)
# Out:
# El número aleatorio es: 16
# La raíz cuadrada de ese número es: 4.0

# %% [markdown]
# #### 📦 Ejercicio 4: El mini módulo
#
# Crea un archivo `mis_utils.py` en la misma carpeta con:
# - Una función `multiplicar(a, b)` que retorne `a * b`.
# - Una función `es_par(n)` que retorne `True` si `n` es par.
#
# Luego, en una celda de este notebook, importa esas funciones y pruébalas.
#
# _(Tu primer módulo personalizado.)_

# %%
import mis_utils
print(mis_utils.multiplicar(3, 5))
print(mis_utils.es_par(7))
# Out:
# 15
# False

# %% [markdown]
# #### ▶️ Ejercicio 5: El patrón `__main__`
#
# Crea un archivo `calculadora.py` con:
# - Una función `sumar(a, b)`.
# - Un bloque `if __name__ == "__main__":` que imprima un mensaje y llame a `sumar(3, 5)`.
#
# Ejecuta el archivo con `python calculadora.py` y verifica que funciona.
# Luego, en una celda, haz `import calculadora` y llama a `calculadora.sumar(10, 20)`. ¿Se ejecutó el mensaje del bloque `__main__`?
#
# _(Porque la misma función puede ser tu programa o solo una pieza.)_

# %%
import calculadora
print(calculadora.sumar(10, 20))
# Out:
# 30

# %% [markdown]
# #### 🗂️ Ejercicio 6: La estructura del proyecto
#
# Diseña en tu mente (o en papel) la estructura de un proyecto llamado `agenda` que tenga:
# - `main.py` con un menú simple.
# - `contactos.py` con funciones para agregar y listar contactos.
# - `config.py` con una constante `ARCHIVO_DATOS = "datos.json"`.
#
# Escribe en una celda cómo importarías desde `main.py` las funciones de `contactos` y la constante de `config`.
#
# _(Planificar antes de codear ahorra dolores de cabeza.)_

# %%
import contactos
import config

contactos.agregar_contacto("Juan", "1234567890")
contactos.agregar_contacto("Ana", "9876543210")

print(contactos.listar_contactos())

print(config.ARCHIVO_DATOS)
# Out:
# [{'nombre': 'Juan', 'telefono': '1234567890'}, {'nombre': 'Ana', 'telefono': '9876543210'}, {'nombre': 'Juan', 'telefono': '1234567890'}, {'nombre': 'Ana', 'telefono': '9876543210'}]
# datos.json

# %% [markdown]
# ---
# ## 🔄 Resumen
#
# | Forma | Sintaxis | Uso |
# | --- | --- | --- |
# | Import completo | `import math` | `math.sqrt(16)` |
# | Import específico | `from math import sqrt` | `sqrt(16)` |
# | Alias | `import math as m` | `m.sqrt(16)` |
# | Alias en import | `from math import sqrt as raiz` | `raiz(16)` |
# | `__main__` | `if __name__ == "__main__":` | Solo al ejecutar el archivo directamente |
