# %% [markdown]
# # Bucles
#
# Las estructuras de iteración permiten repetir secciones de código. A menudo se denominan bucles porque permiten al programa volver a una línea ya ejecutada.
# El proceso de ejecutar una repetición de un bucle también se conoce como iteración del bucle.
#
#
# ## FOR
#
# Un bucle for es una estructura de iteración que:
# - Repite un bloque de código un número determinado de veces
# - Se usa cuando sabemos cuántas veces queremos repetir algo
# - Recorre secuencias como listas, rangos o cadenas de texto

# %%
for variable in secuencia:
    # código que se repite

# %% [markdown]
# ### ⚙️ Elementos de un for (explicación detallada)
# Un for en Python siempre tiene tres piezas:

# %%
for variable in secuencia:
    bloque_de_codigo

# %% [markdown]
# #### 1️⃣ Variable de control
#
# Es la variable que va tomando el valor de cada elemento de la secuencia en cada repetición.
#
# Ejemplo:

# %%
# [0,1,2,3,4]
for numero in range(5):
    print(numero)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Python va asignando automáticamente el valor en cada iteración.

# %% [markdown]
# #### 2️⃣ Secuencia
#
# Es el conjunto de elementos que el for va a recorrer.
#
# Puede ser:
#
# 🔹 range()

# %%
for i in range(5):

# %% [markdown]
# 🔹 lista

# %%
nombres = ["Ana", "Luis", "Carlos"]

for nombre in nombres:
    print(nombre)
# Out:
# Ana
# Luis
# Carlos

# %% [markdown]
# 🔹 texto

# %%
for letra in "amor":
    print(letra)
# Out:
# a
# m
# o
# r

# %% [markdown]
# 🔹 tuplas / diccionarios (más adelante)

# %% [markdown]
# #### 3️⃣ Bloque de código
#
# Es lo que se ejecuta en cada iteración.

# %%
for numero in range(3):
    print("Hola", numero)
# Out:
# Hola 0
# Hola 1
# Hola 2

# %% [markdown]
# Esto se ejecuta 3 veces.
#
# Todo lo que esté indentado pertenece al bucle.

# %% [markdown]
# ### 📌 Regla clave
# - for se usa cuando conocemos la cantidad de repeticiones
# - No depende de una condición como while, sino de una secuencia
# - Recorre elemento por elemento
#
# Ejemplo simple:
#
# range() es una función integrada de Python que genera una secuencia de números enteros, usada principalmente para controlar la cantidad de repeticiones en un bucle for.

# %%
for numero in range(5):
    print(numero)

# %% [markdown]
# ### 🧠 ¿Qué es range()?
#
# range() es una función integrada de Python que genera una secuencia de números enteros, usada principalmente para controlar la cantidad de repeticiones en un bucle for.
#
# No crea una lista visible directamente; produce una secuencia que el for va recorriendo número por número.
#
#
#
# #### 📌 Para qué sirve
#
# Se usa para:
# - repetir un bloque de código varias veces
# - contar
# - iterar con números
# - controlar ciclos for
#
# #### 🧩 Sintaxis

# %%
range(inicio, fin, paso)

# %% [markdown]
# - inicio → desde dónde empieza (opcional)
# - fin → hasta dónde llega (no lo incluye)
# - paso → cuánto avanza cada vez (opcional)

# %% [markdown]
# #### 💻 Formas de usar range()
#
# 1) Solo un número

# %%
for numero in range(5):
    print(numero)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Genera: 0, 1, 2, 3, 4
# Empieza en 0 por defecto.

# %% [markdown]
# 2) Inicio y fin

# %%
for numero in range(1, 6):
    print(numero)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Genera: 1, 2, 3, 4, 5
# El número final no se incluye.

# %% [markdown]
# 3) Inicio, fin y salto

# %%
for numero in range(0, 10, 2):
    print(numero)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
# Genera: 0, 2, 4, 6, 8
# Avanza de 2 en 2.

# %% [markdown]
# #### 💻 Ejemplo típico con for

# %%
for i in range(5):
    print(i)

# %% [markdown]
# #### ⚠️ Concepto importante
#
# - range() no incluye el último número.
# - Por lo tanto range(5) No llega al 5, llega hasta el 4.

# %% [markdown]
# #### 😄 Ejercicios
#
# ##### 1. El amigo intenso
# Tu amigo acaba de enamorarse y ahora dice **"Te extraño"** 5 veces seguidas.

# %%
# aquí tu código
for i in range(1,6):
    print("Te extraño ",i)
# Out:
# Te extraño  1
# Te extraño  2
# Te extraño  3
# Te extraño  4
# Te extraño  5

# %% [markdown]
# ##### 2. El café del programador
#
# Un programador necesita 7 cafés para sobrevivir al lunes. Mostrar cada café que toma.

# %%
# aquí tu código
for i in range(1,8):
    print("Cafe ",i)
# Out:
# Cafe  1
# Cafe  2
# Cafe  3
# Cafe  4
# Cafe  5
# Cafe  6
# Cafe  7

# %% [markdown]
# ##### 3. El contador de flojera
#
# Mostrar del 1 al 10: **"Voy a empezar a hacer ejercicio… mañana"**

# %%
# aquí tu código

# %% [markdown]
# ##### 4. Lista de excusas del estudiante
# Usar la lista de excusas y mostrar cada una:
# `excusas = ["Se me fue el internet", "Mi perro borró el código", "No guardé el archivo", "Pensé que era para mañana"]`

# %%
# aquí tu código
excusas=["se me fue el interenet", " Mi perro borró el código", "No guardé el archivo","Pensé que era para mañana"]
for excusa in excusas:
    print(excusa)
# Out:
# se me fue el interenet
#  Mi perro borró el código
# No guardé el archivo
# Pensé que era para mañana

# %% [markdown]
# ##### 5. Inventario del romántico desesperado
#
# Con `regalos = ["flores", "chocolates", "peluche", "carta"]` mostrar:
# Comprando flores…
# Comprando chocolates…
# etc.

# %%
# aquí tu código
regalos=["flores", "chocolates", "peluches", "carta"]
for regalo in regalos:
    print("comprando ",regalo,"...")
# Out:
# comprando  flores ...
# comprando  chocolates ...
# comprando  peluches ...
# comprando  carta ...

# %% [markdown]
# ##### Ejercicio 6 : Recorriendo un mensaje dramático
#
# Recorrer la palabra **"AYUDA"** e imprimir letra por letra como si fuera alguien gritando.

# %%
# aquí tu código
for letra in "AUXILIO POR FAVOR":
    print(letra)
# Out:
# A
# U
# X
# I
# L
# I
# O
#
# P
# O
# R
#
# F
# A
# V
# O
# R

# %% [markdown]
# #### Ejercicio 7 : Nivel de hambre del estudiante
#
# Simular niveles del 1 al 10 mostrando:
# Nivel de hambre: 1
# Nivel de hambre: 2
# ...
# Nivel de hambre: 10

# %%
# aquí tu código

# %% [markdown]
# ##### Ejercicio 8 : El programador y sus bugs
#
# Con `bugs = ["error login", "pantalla blanca", "no carga API", "no compila"]`
# mostrar: **Arreglando error login...** (y así con cada uno).

# %%
# aquí tu código

# %% [markdown]
# #### 😄 Ejercicio 9 : Amigos que dicen "ya voy"
#
# Con `amigos = ["Carlos", "Luis", "Pedro", "Ana"]` mostrar:
# **Carlos dice: ya voy llegando…** (y así con cada uno).
#
# _(Sabemos que es mentira.)_

# %%
# aquí tu código

# %% [markdown]
# #### 😄 Ejercicio 10 : Simulador de notificaciones
# 🔴 Nivel reto
#
# Mostrar **Nueva notificación 🔔** 10 veces como si fuera WhatsApp en grupo familiar.

# %%
# aquí tu código

# %% [markdown]
# #### 😄 Ejercicio 11 : El gamer que promete "una partida más"
#
# Mostrar 5 veces: **Última partida… lo prometo**

# %%
# aquí tu código

# %% [markdown]
# #### 😄 Ejercicio 12 : El detector de flojera
#
# Recorrer `actividades = ["estudiar", "hacer tarea", "limpiar", "trabajar"]`
# y mostrar: **Pensando en estudiar…** / **Mejor veo TikTok** (para cada una).

# %%
# aquí tu código

# %% [markdown]
# #### 🧠 Ejercicio 13 : El generador de motivación falsa — Ejercicio estrella
#
# Con la lista de frases mostrar cada una como recordatorio del celular:
# `frases = ["Hoy sí empiezo el gym", "Mañana duermo temprano", "Hoy sí estudio", "Hoy no gasto dinero"]`

# %%
# aquí tu código

# %% [markdown]
# #### 🎯 Ejercicio 14 : Contador de rechazos románticos — Bonus
#
# Mostrar: **Intento #1**, **Intento #2**, ... hasta el 10.
#
# _(La programación también enseña resiliencia.)_

# %%
# aquí tu código
