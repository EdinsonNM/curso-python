# %% [markdown]
# # Condicionales

# %%
trae_flores = True
es_impuntual = False

if trae_flores and not es_impuntual:
    print("🌹 ¡Segunda cita asegurada!")
elif trae_flores or not es_impuntual:
    print("🤨 Bueno, le daremos otra oportunidad...")
else:
    print("🏃💨 ¡Huye de ahí, busca a otro!")
# Out:
# 🌹 ¡Segunda cita asegurada!

# %% [markdown]
# ## Bucles
#  Las estructuras de iteración permiten repetir secciones de código. A menudo se denominan bucles porque permiten al programa volver a una línea ya ejecutada. El proceso de ejecutar una repetición de un bucle también se conoce como iteración del bucle.
# ### FOR
